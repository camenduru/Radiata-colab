# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/camenduru/Radiata-colab/blob/main/chilloutmix_radiata_colab.ipynb)

# %%
# %cd /content

# !apt -y install -qq aria2
# !git clone -b v1.0 https://github.com/camenduru/Radiata.git

# %cd /content/Radiata

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/radiata/chilloutmix/raw/main/engine.json -d /content/Radiata/models/accelerate/tensorrt/uf/chilloutmix_NiPrunedFp32Fix -o engine.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/radiata/chilloutmix/resolve/main/engine/unet.plan -d /content/Radiata/models/accelerate/tensorrt/uf/chilloutmix_NiPrunedFp32Fix/engine -o unet.plan
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/radiata/chilloutmix/resolve/main/onnx/unet.onnx -d /content/Radiata/models/accelerate/tensorrt/uf/chilloutmix_NiPrunedFp32Fix/onnx -o unet.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/radiata/chilloutmix/resolve/main/onnx/unet.opt.onnx -d /content/Radiata/models/accelerate/tensorrt/uf/chilloutmix_NiPrunedFp32Fix/onnx -o unet.opt.onnx

# !sed -i 's/runwayml\/stable-diffusion-v1-5/uf\/chilloutmix_NiPrunedFp32Fix/g' /content/Radiata/modules/config.py

# !python launch.py --share --tensorrt
